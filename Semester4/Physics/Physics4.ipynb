# %%
# Out:
# ------------------------------------------------------------
#
# --- Результаты ---
# Начальная скорость частицы 1: (2.0000, 0.0000)
# Начальная скорость частицы 2: (0.0000, 0.0000)
#
# Конечные скорости:
# Частица 1: v1_f = (-0.6361, -0.2841)
# Частица 2: v2_f = (1.3180, 0.1420)
